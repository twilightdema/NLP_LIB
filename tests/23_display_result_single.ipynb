# %%
import os
import sys
import csv
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from mpl_toolkits.axes_grid1 import ImageGrid
import pickle
from IPython.display import display
import seaborn

# %%
DISPLAY_ROUND = 10
NUM_HEAD = 4

OUTPUT_FILE = os.path.join('output_logs', '23_output_trial_0.csv')
with open(OUTPUT_FILE, 'r') as fin:
    data_iter = csv.reader(fin)
    data = [np.array(data) for data in data_iter]
data_array = np.array(data)
header_array = data_array[0]
data_array = data_array[1:]
data_array = data_array.astype(np.float32)

# %%
comm_rounds = data_array[:DISPLAY_ROUND,0].astype(np.int)
fedAvg_test_loss = data_array[:DISPLAY_ROUND,17]
matched_fedAvg_test_loss = data_array[:DISPLAY_ROUND,18]
fedAvg_test_disagreement_loss = data_array[:DISPLAY_ROUND,19]
matched_fedAvg_test_disagreement_loss = data_array[:DISPLAY_ROUND,20]
fedAvg_test_classification_loss = data_array[:DISPLAY_ROUND,21]
matched_fedAvg_test_classification_loss = data_array[:DISPLAY_ROUND,22]
fedAvg_test_accuracy = data_array[:DISPLAY_ROUND,23]
matched_fedAvg_test_accuracy = data_array[:DISPLAY_ROUND,24]
fedAVG_local_loss_1 = data_array[:DISPLAY_ROUND,1]
fedAVG_local_loss_2 = data_array[:DISPLAY_ROUND,2]
matched_fedAVG_local_loss_1 = data_array[:DISPLAY_ROUND,3]
matched_fedAVG_local_loss_2 = data_array[:DISPLAY_ROUND,4]
fedAVG_local_disagreement_loss_1 = data_array[:DISPLAY_ROUND,5]
fedAVG_local_disagreement_loss_2 = data_array[:DISPLAY_ROUND,6]
matched_fedAVG_local_disagreement_loss_1 = data_array[:DISPLAY_ROUND,7]
matched_fedAVG_local_disagreement_loss_2 = data_array[:DISPLAY_ROUND,8]
fedAVG_local_classification_loss_1 = data_array[:DISPLAY_ROUND,9]
fedAVG_local_classification_loss_2 = data_array[:DISPLAY_ROUND,10]
matched_fedAVG_local_classification_loss_1 = data_array[:DISPLAY_ROUND,11]
matched_fedAVG_local_classification_loss_2 = data_array[:DISPLAY_ROUND,12]
fedAVG_local_accuracy_1 = data_array[:DISPLAY_ROUND,13]
fedAVG_local_accuracy_2 = data_array[:DISPLAY_ROUND,14]
matched_fedAVG_local_accuracy_1 = data_array[:DISPLAY_ROUND,15]
matched_fedAVG_local_accuracy_2 = data_array[:DISPLAY_ROUND,16]
plt.plot(comm_rounds, fedAvg_test_loss, marker='o', label='Worst Matched FedAvg')
plt.plot(comm_rounds, matched_fedAvg_test_loss, marker='o', label='Best Matched FedAVG')
plt.title('Non-IID Loss Comparison (Local Training = 10 Epochs)')
plt.xlabel('Communication Round')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc="upper right")
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
#plt.ylim(0.15, 0.4)
plt.show()

# %%
comm_rounds = data_array[:DISPLAY_ROUND,0].astype(np.int)
fedAvg_test_loss = data_array[:DISPLAY_ROUND,17]
matched_fedAvg_test_loss = data_array[:DISPLAY_ROUND,18]
fedAvg_test_disagreement_loss = data_array[:DISPLAY_ROUND,19]
matched_fedAvg_test_disagreement_loss = data_array[:DISPLAY_ROUND,20]
fedAvg_test_classification_loss = data_array[:DISPLAY_ROUND,21]
matched_fedAvg_test_classification_loss = data_array[:DISPLAY_ROUND,22]
fedAvg_test_accuracy = data_array[:DISPLAY_ROUND,23]
matched_fedAvg_test_accuracy = data_array[:DISPLAY_ROUND,24]
fedAVG_local_loss_1 = data_array[:DISPLAY_ROUND,1]
fedAVG_local_loss_2 = data_array[:DISPLAY_ROUND,2]
matched_fedAVG_local_loss_1 = data_array[:DISPLAY_ROUND,3]
matched_fedAVG_local_loss_2 = data_array[:DISPLAY_ROUND,4]
fedAVG_local_disagreement_loss_1 = data_array[:DISPLAY_ROUND,5]
fedAVG_local_disagreement_loss_2 = data_array[:DISPLAY_ROUND,6]
matched_fedAVG_local_disagreement_loss_1 = data_array[:DISPLAY_ROUND,7]
matched_fedAVG_local_disagreement_loss_2 = data_array[:DISPLAY_ROUND,8]
fedAVG_local_classification_loss_1 = data_array[:DISPLAY_ROUND,9]
fedAVG_local_classification_loss_2 = data_array[:DISPLAY_ROUND,10]
matched_fedAVG_local_classification_loss_1 = data_array[:DISPLAY_ROUND,11]
matched_fedAVG_local_classification_loss_2 = data_array[:DISPLAY_ROUND,12]
fedAVG_local_accuracy_1 = data_array[:DISPLAY_ROUND,13]
fedAVG_local_accuracy_2 = data_array[:DISPLAY_ROUND,14]
matched_fedAVG_local_accuracy_1 = data_array[:DISPLAY_ROUND,15]
matched_fedAVG_local_accuracy_2 = data_array[:DISPLAY_ROUND,16]
plt.plot(comm_rounds, fedAVG_local_loss_1, marker='o', label='Worst Matched FedAVG Train (1)')
plt.plot(comm_rounds, fedAVG_local_loss_2, marker='o', label='Worst Matched FedAVG Train (2)')
plt.plot(comm_rounds, matched_fedAVG_local_loss_1, marker='o', label='Best Matched FedAVG Train (1)')
plt.plot(comm_rounds, matched_fedAVG_local_loss_2, marker='o', label='Best Matched FedAVG Train (2)')
plt.title('Non-IID Loss Comparison (Local Training = 10 Epochs)')
plt.xlabel('Communication Round')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc="upper right")
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
#plt.ylim(0.15, 0.4)
plt.show()

# %%
comm_rounds = data_array[:DISPLAY_ROUND,0].astype(np.int)
fedAvg_test_loss = data_array[:DISPLAY_ROUND,17]
matched_fedAvg_test_loss = data_array[:DISPLAY_ROUND,18]
fedAvg_test_disagreement_loss = data_array[:DISPLAY_ROUND,19]
matched_fedAvg_test_disagreement_loss = data_array[:DISPLAY_ROUND,20]
fedAvg_test_classification_loss = data_array[:DISPLAY_ROUND,21]
matched_fedAvg_test_classification_loss = data_array[:DISPLAY_ROUND,22]
fedAvg_test_accuracy = data_array[:DISPLAY_ROUND,23]
matched_fedAvg_test_accuracy = data_array[:DISPLAY_ROUND,24]
fedAVG_local_loss_1 = data_array[:DISPLAY_ROUND,1]
fedAVG_local_loss_2 = data_array[:DISPLAY_ROUND,2]
matched_fedAVG_local_loss_1 = data_array[:DISPLAY_ROUND,3]
matched_fedAVG_local_loss_2 = data_array[:DISPLAY_ROUND,4]
fedAVG_local_disagreement_loss_1 = data_array[:DISPLAY_ROUND,5]
fedAVG_local_disagreement_loss_2 = data_array[:DISPLAY_ROUND,6]
matched_fedAVG_local_disagreement_loss_1 = data_array[:DISPLAY_ROUND,7]
matched_fedAVG_local_disagreement_loss_2 = data_array[:DISPLAY_ROUND,8]
fedAVG_local_classification_loss_1 = data_array[:DISPLAY_ROUND,9]
fedAVG_local_classification_loss_2 = data_array[:DISPLAY_ROUND,10]
matched_fedAVG_local_classification_loss_1 = data_array[:DISPLAY_ROUND,11]
matched_fedAVG_local_classification_loss_2 = data_array[:DISPLAY_ROUND,12]
fedAVG_local_accuracy_1 = data_array[:DISPLAY_ROUND,13]
fedAVG_local_accuracy_2 = data_array[:DISPLAY_ROUND,14]
matched_fedAVG_local_accuracy_1 = data_array[:DISPLAY_ROUND,15]
matched_fedAVG_local_accuracy_2 = data_array[:DISPLAY_ROUND,16]
plt.plot(comm_rounds, fedAVG_local_accuracy_1, marker='o', label='Worst Matched FedAVG Train (1)')
plt.plot(comm_rounds, fedAVG_local_accuracy_2, marker='o', label='Worst Matched FedAVG Train (2)')
plt.plot(comm_rounds, matched_fedAVG_local_accuracy_1, marker='o', label='Best Matched FedAVG Train (1)')
plt.plot(comm_rounds, matched_fedAVG_local_accuracy_2, marker='o', label='Best Matched FedAVG Train (2)')
plt.title('Non-IID Accuracy (Local Training = 10 Epochs)')
plt.xlabel('Communication Round')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc="upper right")
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
#plt.ylim(0.15, 0.4)
plt.show()

# %%
comm_rounds = data_array[:DISPLAY_ROUND,0].astype(np.int)
fedAvg_test_loss = data_array[:DISPLAY_ROUND,17]
matched_fedAvg_test_loss = data_array[:DISPLAY_ROUND,18]
fedAvg_test_disagreement_loss = data_array[:DISPLAY_ROUND,19]
matched_fedAvg_test_disagreement_loss = data_array[:DISPLAY_ROUND,20]
fedAvg_test_classification_loss = data_array[:DISPLAY_ROUND,21]
matched_fedAvg_test_classification_loss = data_array[:DISPLAY_ROUND,22]
fedAvg_test_accuracy = data_array[:DISPLAY_ROUND,23]
matched_fedAvg_test_accuracy = data_array[:DISPLAY_ROUND,24]
fedAVG_local_loss_1 = data_array[:DISPLAY_ROUND,1]
fedAVG_local_loss_2 = data_array[:DISPLAY_ROUND,2]
matched_fedAVG_local_loss_1 = data_array[:DISPLAY_ROUND,3]
matched_fedAVG_local_loss_2 = data_array[:DISPLAY_ROUND,4]
fedAVG_local_disagreement_loss_1 = data_array[:DISPLAY_ROUND,5]
fedAVG_local_disagreement_loss_2 = data_array[:DISPLAY_ROUND,6]
matched_fedAVG_local_disagreement_loss_1 = data_array[:DISPLAY_ROUND,7]
matched_fedAVG_local_disagreement_loss_2 = data_array[:DISPLAY_ROUND,8]
fedAVG_local_classification_loss_1 = data_array[:DISPLAY_ROUND,9]
fedAVG_local_classification_loss_2 = data_array[:DISPLAY_ROUND,10]
matched_fedAVG_local_classification_loss_1 = data_array[:DISPLAY_ROUND,11]
matched_fedAVG_local_classification_loss_2 = data_array[:DISPLAY_ROUND,12]
fedAVG_local_accuracy_1 = data_array[:DISPLAY_ROUND,13]
fedAVG_local_accuracy_2 = data_array[:DISPLAY_ROUND,14]
matched_fedAVG_local_accuracy_1 = data_array[:DISPLAY_ROUND,15]
matched_fedAVG_local_accuracy_2 = data_array[:DISPLAY_ROUND,16]
plt.plot(comm_rounds, fedAvg_test_classification_loss, marker='o', label='Worst Matched FedAVG')
plt.plot(comm_rounds, matched_fedAvg_test_classification_loss, marker='o', label='Best Matched FedAVG')
plt.title('Non-IID Classification Loss Comparison (Local Training = 10 Epochs)')
plt.xlabel('Communication Round')
plt.ylabel('Classification Loss')
plt.grid(True)
plt.legend(loc="upper right")
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
#plt.ylim(0.15, 0.4)
plt.show()

# %%
comm_rounds = data_array[:DISPLAY_ROUND,0].astype(np.int)
fedAvg_test_loss = data_array[:DISPLAY_ROUND,17]
matched_fedAvg_test_loss = data_array[:DISPLAY_ROUND,18]
fedAvg_test_disagreement_loss = data_array[:DISPLAY_ROUND,19]
matched_fedAvg_test_disagreement_loss = data_array[:DISPLAY_ROUND,20]
fedAvg_test_classification_loss = data_array[:DISPLAY_ROUND,21]
matched_fedAvg_test_classification_loss = data_array[:DISPLAY_ROUND,22]
fedAvg_test_accuracy = data_array[:DISPLAY_ROUND,23]
matched_fedAvg_test_accuracy = data_array[:DISPLAY_ROUND,24]
fedAVG_local_loss_1 = data_array[:DISPLAY_ROUND,1]
fedAVG_local_loss_2 = data_array[:DISPLAY_ROUND,2]
matched_fedAVG_local_loss_1 = data_array[:DISPLAY_ROUND,3]
matched_fedAVG_local_loss_2 = data_array[:DISPLAY_ROUND,4]
fedAVG_local_disagreement_loss_1 = data_array[:DISPLAY_ROUND,5]
fedAVG_local_disagreement_loss_2 = data_array[:DISPLAY_ROUND,6]
matched_fedAVG_local_disagreement_loss_1 = data_array[:DISPLAY_ROUND,7]
matched_fedAVG_local_disagreement_loss_2 = data_array[:DISPLAY_ROUND,8]
fedAVG_local_classification_loss_1 = data_array[:DISPLAY_ROUND,9]
fedAVG_local_classification_loss_2 = data_array[:DISPLAY_ROUND,10]
matched_fedAVG_local_classification_loss_1 = data_array[:DISPLAY_ROUND,11]
matched_fedAVG_local_classification_loss_2 = data_array[:DISPLAY_ROUND,12]
fedAVG_local_accuracy_1 = data_array[:DISPLAY_ROUND,13]
fedAVG_local_accuracy_2 = data_array[:DISPLAY_ROUND,14]
matched_fedAVG_local_accuracy_1 = data_array[:DISPLAY_ROUND,15]
matched_fedAVG_local_accuracy_2 = data_array[:DISPLAY_ROUND,16]
plt.plot(comm_rounds, fedAvg_test_disagreement_loss, marker='o', label='Worst Matched FedAVG')
plt.plot(comm_rounds, matched_fedAvg_test_disagreement_loss, marker='o', label='Best Matched FedAVG')
plt.title('Non-IID Disagreement Loss Comparison (Local Training = 10 Epochs)')
plt.xlabel('Communication Round')
plt.ylabel('Disagreement Loss')
plt.grid(True)
plt.legend(loc="upper right")
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
#plt.ylim(0.15, 0.4)
plt.show()

# %%
comm_rounds = data_array[:DISPLAY_ROUND,0].astype(np.int)
fedAvg_test_loss = data_array[:DISPLAY_ROUND,17]
matched_fedAvg_test_loss = data_array[:DISPLAY_ROUND,18]
fedAvg_test_disagreement_loss = data_array[:DISPLAY_ROUND,19]
matched_fedAvg_test_disagreement_loss = data_array[:DISPLAY_ROUND,20]
fedAvg_test_classification_loss = data_array[:DISPLAY_ROUND,21]
matched_fedAvg_test_classification_loss = data_array[:DISPLAY_ROUND,22]
fedAvg_test_accuracy = data_array[:DISPLAY_ROUND,23]
matched_fedAvg_test_accuracy = data_array[:DISPLAY_ROUND,24]
fedAVG_local_loss_1 = data_array[:DISPLAY_ROUND,1]
fedAVG_local_loss_2 = data_array[:DISPLAY_ROUND,2]
matched_fedAVG_local_loss_1 = data_array[:DISPLAY_ROUND,3]
matched_fedAVG_local_loss_2 = data_array[:DISPLAY_ROUND,4]
fedAVG_local_disagreement_loss_1 = data_array[:DISPLAY_ROUND,5]
fedAVG_local_disagreement_loss_2 = data_array[:DISPLAY_ROUND,6]
matched_fedAVG_local_disagreement_loss_1 = data_array[:DISPLAY_ROUND,7]
matched_fedAVG_local_disagreement_loss_2 = data_array[:DISPLAY_ROUND,8]
fedAVG_local_classification_loss_1 = data_array[:DISPLAY_ROUND,9]
fedAVG_local_classification_loss_2 = data_array[:DISPLAY_ROUND,10]
matched_fedAVG_local_classification_loss_1 = data_array[:DISPLAY_ROUND,11]
matched_fedAVG_local_classification_loss_2 = data_array[:DISPLAY_ROUND,12]
fedAVG_local_accuracy_1 = data_array[:DISPLAY_ROUND,13]
fedAVG_local_accuracy_2 = data_array[:DISPLAY_ROUND,14]
matched_fedAVG_local_accuracy_1 = data_array[:DISPLAY_ROUND,15]
matched_fedAVG_local_accuracy_2 = data_array[:DISPLAY_ROUND,16]
plt.plot(comm_rounds, fedAvg_test_accuracy, marker='o', label='Worst Matched FedAVG')
plt.plot(comm_rounds, matched_fedAvg_test_accuracy, marker='o', label='Best Matched FedAVG')
plt.title('Non-IID Accuracy (Local Training = 10 Epochs)')
plt.xlabel('Communication Round')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc="upper right")
plt.gca().xaxis.set_major_locator(mticker.MultipleLocator(1))
#plt.ylim(0.15, 0.4)
plt.show()

# %%
algor = 'FedAVG'
log_prefix = os.path.join('weight_logs', '23_benchmark_fedma_trial_0_')
EPOCH = 8
for epoch in range(EPOCH):
    print('Worst Matched FedAVG, 10 Local Epochs, Communication Round: ' + str(epoch))
    log_file = log_prefix + str(epoch) + '.pkl'
    node_weights = None
    with open(log_file, 'rb') as fin:
        node_weights = pickle.load(fin)
    node_count = len(node_weights)

    fig = plt.figure(figsize=(7., 4.))
    grid = ImageGrid(fig, 111,  # similar to subplot(111)
         nrows_ncols=(2, 8),  # creates 2x8 grid of axes
         axes_pad=0.1,  # pad between axes in inch.
         )    
    for node in range(node_count):
        node_weight = node_weights[node]
        K_kernel, K_bias, Q_kernel, Q_bias, V_kernel, V_bias, output_kernel, output_bias, prediction_kernel, prediction_bias, embedding_kernel = node_weight
        
        K_kernel_range = np.max(K_kernel) - np.min(K_kernel)
        K_bias_range = np.max(K_bias) - np.min(K_bias)
        Q_kernel_range = np.max(Q_kernel) - np.min(Q_kernel)
        Q_bias_range = np.max(Q_bias) - np.min(Q_bias)
        V_kernel_range = np.max(V_kernel) - np.min(V_kernel)
        V_bias_range = np.max(V_bias) - np.min(V_bias)
        output_kernel_range = np.max(output_kernel) - np.min(output_kernel)
        output_bias_range = np.max(output_bias) - np.min(output_bias)
        print('Range K = ' + str(K_kernel_range) + ' / ' + str(K_bias_range))
        print('Range Q = ' + str(Q_kernel_range) + ' / ' + str(Q_bias_range))
        print('Range V = ' + str(V_kernel_range) + ' / ' + str(V_bias_range))
        print('Range output = ' + str(output_kernel_range) + ' / ' + str(output_bias_range))
        
        
        grid[node * 8 + 0].imshow(K_kernel, cmap='hot', interpolation='nearest')
        grid[node * 8 + 0].axis('off')
        grid[node * 8 + 1].imshow(np.stack([K_bias for _ in range(K_bias.shape[0])], axis=0), cmap='hot', interpolation='nearest')
        grid[node * 8 + 1].axis('off')
        grid[node * 8 + 2].imshow(Q_kernel, cmap='hot', interpolation='nearest')
        grid[node * 8 + 2].axis('off')
        grid[node * 8 + 3].imshow(np.stack([Q_bias for _ in range(Q_bias.shape[0])], axis=0), cmap='hot', interpolation='nearest')
        grid[node * 8 + 3].axis('off')
        grid[node * 8 + 4].imshow(V_kernel, cmap='hot', interpolation='nearest')
        grid[node * 8 + 4].axis('off')
        grid[node * 8 + 5].imshow(np.stack([V_bias for _ in range(V_bias.shape[0])], axis=0), cmap='hot', interpolation='nearest')
        grid[node * 8 + 5].axis('off')
        grid[node * 8 + 6].imshow(output_kernel, cmap='hot', interpolation='nearest')
        grid[node * 8 + 6].axis('off')
        grid[node * 8 + 7].imshow(np.stack([output_bias for _ in range(output_bias.shape[0])], axis=0), cmap='hot', interpolation='nearest')
        grid[node * 8 + 7].axis('off')
    
    display(fig)
    plt.close()
# Out:
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 0
# Range K = 0.49936378 / 1.8828661e-10
# Range Q = 0.5010253 / 0.0014783796
# Range V = 0.50453377 / 0.0049946588
# Range output = 0.5110873 / 0.0036628053
# Range K = 0.49971837 / 6.041474e-11
# Range Q = 0.49971056 / 0.003658032
# Range V = 0.5068522 / 0.0027107303
# Range output = 0.5057018 / 0.002293835
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 1
# Range K = 0.48235258 / 4.3919222e-11
# Range Q = 0.48438638 / 0.0017318892
# Range V = 0.4879486 / 0.0097115785
# Range output = 0.4927071 / 0.014890968
# Range K = 0.4823674 / 6.595511e-11
# Range Q = 0.48442042 / 0.0025006658
# Range V = 0.49254823 / 0.017935578
# Range output = 0.4972855 / 0.027253464
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 2
# Range K = 0.48243022 / 8.009176e-11
# Range Q = 0.48439753 / 0.0018793086
# Range V = 0.4881227 / 0.010115755
# Range output = 0.49399865 / 0.015597735
# Range K = 0.48240197 / 6.914175e-11
# Range Q = 0.4843871 / 0.0027745499
# Range V = 0.4926111 / 0.018438416
# Range output = 0.49857366 / 0.0280083
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 3
# Range K = 0.48247254 / 1.1984891e-10
# Range Q = 0.4843676 / 0.002022156
# Range V = 0.4880234 / 0.010243973
# Range output = 0.49474174 / 0.015794976
# Range K = 0.48244095 / 5.5469046e-11
# Range Q = 0.4843508 / 0.0029220236
# Range V = 0.49247092 / 0.018548002
# Range output = 0.49927333 / 0.028163284
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 4
# Range K = 0.4825061 / 1.0568885e-10
# Range Q = 0.48433214 / 0.002342269
# Range V = 0.48782364 / 0.010273801
# Range output = 0.4952519 / 0.015800938
# Range K = 0.48247677 / 6.315911e-11
# Range Q = 0.4843089 / 0.0030092946
# Range V = 0.49223274 / 0.018528484
# Range output = 0.49973118 / 0.028119743
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 5
# Range K = 0.48253578 / 1.3372616e-10
# Range Q = 0.4842899 / 0.0026453563
# Range V = 0.48755777 / 0.010274148
# Range output = 0.49566358 / 0.015748018
# Range K = 0.48250958 / 1.9887252e-10
# Range Q = 0.4842646 / 0.0031402726
# Range V = 0.49197483 / 0.018467702
# Range output = 0.50009793 / 0.028013263
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 6
# Range K = 0.48256332 / 1.09718054e-10
# Range Q = 0.48424077 / 0.0029344491
# Range V = 0.4872738 / 0.010270142
# Range output = 0.49604046 / 0.015685244
# Range K = 0.4825401 / 1.0668219e-10
# Range Q = 0.48421612 / 0.0034255874
# Range V = 0.49170274 / 0.018398214
# Range output = 0.5004083 / 0.02789408
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 7
# Range K = 0.4825893 / 9.030211e-11
# Range Q = 0.48418838 / 0.003215691
# Range V = 0.48699057 / 0.0102698
# Range output = 0.49638274 / 0.015629897
# Range K = 0.4825658 / 1.3600579e-10
# Range Q = 0.4841599 / 0.0037012475
# Range V = 0.4914187 / 0.018330812
# Range output = 0.500716 / 0.027778514

# %%
algor = 'Matched-FedAVG'
log_prefix = os.path.join('weight_logs', '23_benchmark_mfedma_trial_0_')
EPOCH = 8
for epoch in range(EPOCH):
    print('Best Matched FedAVG, 10 Local Epochs, Communication Round: ' + str(epoch))
    log_file = log_prefix + str(epoch) + '.pkl'
    node_weights = None
    with open(log_file, 'rb') as fin:
        node_weights = pickle.load(fin)
    node_count = len(node_weights)

    fig = plt.figure(figsize=(7., 4.))
    grid = ImageGrid(fig, 111,  # similar to subplot(111)
         nrows_ncols=(2, 8),  # creates 2x8 grid of axes
         axes_pad=0.1,  # pad between axes in inch.
         )    
    for node in range(node_count):
        node_weight = node_weights[node]
        K_kernel, K_bias, Q_kernel, Q_bias, V_kernel, V_bias, output_kernel, output_bias, prediction_kernel, prediction_bias, embedding_kernel = node_weight 
        
        K_kernel_range = np.max(K_kernel) - np.min(K_kernel)
        K_bias_range = np.max(K_bias) - np.min(K_bias)
        Q_kernel_range = np.max(Q_kernel) - np.min(Q_kernel)
        Q_bias_range = np.max(Q_bias) - np.min(Q_bias)
        V_kernel_range = np.max(V_kernel) - np.min(V_kernel)
        V_bias_range = np.max(V_bias) - np.min(V_bias)
        output_kernel_range = np.max(output_kernel) - np.min(output_kernel)
        output_bias_range = np.max(output_bias) - np.min(output_bias)
        
        print('Range K = ' + str(K_kernel_range) + ' / ' + str(K_bias_range))
        print('Range Q = ' + str(Q_kernel_range) + ' / ' + str(Q_bias_range))
        print('Range V = ' + str(V_kernel_range) + ' / ' + str(V_bias_range))
        print('Range output = ' + str(output_kernel_range) + ' / ' + str(output_bias_range))
        
        grid[node * 8 + 0].imshow(K_kernel, cmap='hot', interpolation='nearest')
        grid[node * 8 + 0].axis('off')
        grid[node * 8 + 1].imshow(np.stack([K_bias for _ in range(K_bias.shape[0])], axis=0), cmap='hot', interpolation='nearest')
        grid[node * 8 + 1].axis('off')
        grid[node * 8 + 2].imshow(Q_kernel, cmap='hot', interpolation='nearest')
        grid[node * 8 + 2].axis('off')
        grid[node * 8 + 3].imshow(np.stack([Q_bias for _ in range(Q_bias.shape[0])], axis=0), cmap='hot', interpolation='nearest')
        grid[node * 8 + 3].axis('off')
        grid[node * 8 + 4].imshow(V_kernel, cmap='hot', interpolation='nearest')
        grid[node * 8 + 4].axis('off')
        grid[node * 8 + 5].imshow(np.stack([V_bias for _ in range(V_bias.shape[0])], axis=0), cmap='hot', interpolation='nearest')
        grid[node * 8 + 5].axis('off')
        grid[node * 8 + 6].imshow(output_kernel, cmap='hot', interpolation='nearest')
        grid[node * 8 + 6].axis('off')
        grid[node * 8 + 7].imshow(np.stack([output_bias for _ in range(output_bias.shape[0])], axis=0), cmap='hot', interpolation='nearest')
        grid[node * 8 + 7].axis('off')
    
    display(fig)
    plt.close()
# Out:
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 0
# Range K = 0.49936378 / 1.8828661e-10
# Range Q = 0.5010253 / 0.0014783796
# Range V = 0.50453377 / 0.0049946588
# Range output = 0.5110873 / 0.0036628053
# Range K = 0.49971837 / 6.041474e-11
# Range Q = 0.49971056 / 0.003658032
# Range V = 0.5068522 / 0.0027107303
# Range output = 0.5057018 / 0.002293835
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 1
# Range K = 0.48169088 / 1.253804e-10
# Range Q = 0.48536113 / 0.0024490529
# Range V = 0.4859513 / 0.00994098
# Range output = 0.4851939 / 0.016184933
# Range K = 0.48158163 / 9.9368486e-11
# Range Q = 0.48540044 / 0.002643234
# Range V = 0.48908734 / 0.015855256
# Range output = 0.48882765 / 0.025316378
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 2
# Range K = 0.48169774 / 1.1774381e-10
# Range Q = 0.4853416 / 0.0024442063
# Range V = 0.48677307 / 0.010310031
# Range output = 0.48595154 / 0.01675723
# Range K = 0.48158413 / 1.2236043e-10
# Range Q = 0.48538694 / 0.0026908347
# Range V = 0.48971334 / 0.016243272
# Range output = 0.48963505 / 0.025963694
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 3
# Range K = 0.48169985 / 1.1967455e-10
# Range Q = 0.48532182 / 0.0025269003
# Range V = 0.48728287 / 0.010602851
# Range output = 0.4865631 / 0.017202653
# Range K = 0.48158252 / 1.1535246e-10
# Range Q = 0.48537064 / 0.0027826477
# Range V = 0.49008292 / 0.016497506
# Range output = 0.49026155 / 0.02640099
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 4
# Range K = 0.4816981 / 1.3276906e-10
# Range Q = 0.48530173 / 0.0026029118
# Range V = 0.48766512 / 0.010847993
# Range output = 0.48709893 / 0.017571926
# Range K = 0.4815759 / 1.4078248e-10
# Range Q = 0.4853568 / 0.0028616372
# Range V = 0.49036866 / 0.0166932
# Range output = 0.4908225 / 0.026743464
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 5
# Range K = 0.48169327 / 1.236656e-10
# Range Q = 0.48528346 / 0.0026693828
# Range V = 0.48799878 / 0.011063394
# Range output = 0.4876192 / 0.01789615
# Range K = 0.48156893 / 1.4581464e-10
# Range Q = 0.48534453 / 0.002928645
# Range V = 0.4906376 / 0.016856901
# Range output = 0.4913415 / 0.027031243
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 6
# Range K = 0.48168814 / 1.2241907e-10
# Range Q = 0.4852677 / 0.0027255653
# Range V = 0.4883271 / 0.011257298
# Range output = 0.48812085 / 0.018189995
# Range K = 0.48155963 / 1.7392232e-10
# Range Q = 0.48533288 / 0.00298456
# Range V = 0.49087292 / 0.017000146
# Range output = 0.4918415 / 0.027282316
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 7
# Range K = 0.48168105 / 1.6157801e-10
# Range Q = 0.48525319 / 0.002771608
# Range V = 0.48863894 / 0.011434254
# Range output = 0.48861325 / 0.018460829
# Range K = 0.48155004 / 1.484973e-10
# Range Q = 0.48532137 / 0.003030159
# Range V = 0.49113464 / 0.017128542
# Range output = 0.49232993 / 0.027505575

# %%
algor = 'FedAVG'
log_prefix = os.path.join('attention_logs', '23_benchmark_fedma_trial_0_')
EPOCH = 8
for epoch in range(EPOCH):
    print('Worst Matched FedAVG, 10 Local Epochs, Communication Round: ' + str(epoch))
    log_file = log_prefix + str(epoch) + '.pkl'
    attention_logs = None
    with open(log_file, 'rb') as fin:
        attention_logs = pickle.load(fin)
    sampled_input_vals, sampled_attention_probs, sampled_logprob_vals = attention_logs
    heads = sampled_attention_probs.shape[1]
    
    batch = 1
    # Do not show <PAD> tokens
    last_pos = 0
    for i in range(len(sampled_input_vals[0])):
        token_id = sampled_input_vals[batch][i]
        if token_id == 0 or token_id == 3:
            last_pos = i
            break
    sampled_input_vals[batch] = sampled_input_vals[batch][:last_pos]
    sampled_attention_probs = sampled_attention_probs[:,:, :last_pos, :last_pos]
    sampled_logprob_vals = sampled_logprob_vals[:, :last_pos]

    fig, axs = plt.subplots(1, heads, figsize=(20, 10))

    attention_min = np.min(sampled_attention_probs[batch])
    attention_max = np.max(sampled_attention_probs[batch])
    attention_range = attention_max - attention_min
    print('Attention Values: Min = ' + str(attention_min) + ', Max = ' + str(attention_max) + ', Range = ' + str(attention_range))
    
    for head in range(heads):
        inputs = sampled_input_vals[batch]
        attentions = sampled_attention_probs[batch][head]
        seaborn.heatmap(attentions, 
                    xticklabels=inputs, square=True, yticklabels=inputs, vmin=0.0, vmax=0.2, 
                    cbar=False, ax=axs[head])
    plt.show()
# Out:
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 0
# Attention Values: Min = 0.03857686, Max = 0.07450181, Range = 0.035924952
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 1
# Attention Values: Min = 0.038804617, Max = 0.074723564, Range = 0.035918947
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 2
# Attention Values: Min = 0.03887007, Max = 0.07474397, Range = 0.0358739
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 3
# Attention Values: Min = 0.038899112, Max = 0.0747561, Range = 0.03585699
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 4
# Attention Values: Min = 0.038911752, Max = 0.07476421, Range = 0.035852455
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 5
# Attention Values: Min = 0.03891608, Max = 0.07476855, Range = 0.03585247
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 6
# Attention Values: Min = 0.038915124, Max = 0.0747707, Range = 0.035855573
# Worst Matched FedAVG, 10 Local Epochs, Communication Round: 7
# Attention Values: Min = 0.03891096, Max = 0.07477, Range = 0.035859045

# %%
algor = 'Matched-FedAVG'
log_prefix = os.path.join('attention_logs', '23_benchmark_mfedma_trial_0_')
EPOCH = 8
for epoch in range(EPOCH):
    print('Best Matched FedAVG, 10 Local Epochs, Communication Round: ' + str(epoch))
    log_file = log_prefix + str(epoch) + '.pkl'
    attention_logs = None
    with open(log_file, 'rb') as fin:
        attention_logs = pickle.load(fin)
    sampled_input_vals, sampled_attention_probs, sampled_logprob_vals = attention_logs
    heads = sampled_attention_probs.shape[1]
    
    batch = 1
    # Do not show <PAD> tokens
    last_pos = 0
    for i in range(len(sampled_input_vals[0])):
        token_id = sampled_input_vals[batch][i]
        if token_id == 0 or token_id == 3:
            last_pos = i
            break
    sampled_input_vals[batch] = sampled_input_vals[batch][:last_pos]
    sampled_attention_probs = sampled_attention_probs[:,:, :last_pos, :last_pos]
    sampled_logprob_vals = sampled_logprob_vals[:, :last_pos]
    
    fig, axs = plt.subplots(1, heads, figsize=(20, 10))

    attention_min = np.min(sampled_attention_probs[batch])
    attention_max = np.max(sampled_attention_probs[batch])
    attention_range = attention_max - attention_min
    print('Attention Values: Min = ' + str(attention_min) + ', Max = ' + str(attention_max) + ', Range = ' + str(attention_range))
    
    for head in range(heads):
        inputs = sampled_input_vals[batch]
        attentions = sampled_attention_probs[batch][head]
        seaborn.heatmap(attentions, 
                    xticklabels=inputs, square=True, yticklabels=inputs, vmin=0.0, vmax=0.2, 
                    cbar=False, ax=axs[head])
    plt.show()
# Out:
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 0
# Attention Values: Min = 0.03690007, Max = 0.08333325, Range = 0.046433177
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 1
# Attention Values: Min = 0.036961988, Max = 0.0834255, Range = 0.046463512
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 2
# Attention Values: Min = 0.036956288, Max = 0.083326235, Range = 0.046369947
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 3
# Attention Values: Min = 0.036950838, Max = 0.08322461, Range = 0.04627377
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 4
# Attention Values: Min = 0.036946334, Max = 0.083129264, Range = 0.04618293
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 5
# Attention Values: Min = 0.036943294, Max = 0.083042644, Range = 0.04609935
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 6
# Attention Values: Min = 0.036941748, Max = 0.08296606, Range = 0.04602431
# Best Matched FedAVG, 10 Local Epochs, Communication Round: 7
# Attention Values: Min = 0.036941767, Max = 0.082899354, Range = 0.045957588
